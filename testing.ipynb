# %%
import pandas as pd

# %%
df = pd.read_csv("tweet_emotions.csv")

# %%
df.sentiment.unique()
# Out:
# array(['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
#        'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger'],
#       dtype=object)

# %%
pd.set_option('display.max_colwidth', None)
df.head(30)
# Out:
#       tweet_id   sentiment  \
# 0   1956967341       empty
# 1   1956967666     sadness
# 2   1956967696     sadness
# 3   1956967789  enthusiasm
# 4   1956968416     neutral
# 5   1956968477       worry
# 6   1956968487     sadness
# 7   1956968636       worry
# 8   1956969035     sadness
# 9   1956969172     sadness
# 10  1956969456     neutral
# 11  1956969531       worry
# 12  1956970047     sadness
# 13  1956970424     sadness
# 14  1956970860    surprise
# 15  1956971077     sadness
# 16  1956971170        love
# 17  1956971206     sadness
# 18  1956971473       worry
# 19  1956971586     sadness
# 20  1956971981       worry
# 21  1956972097         fun
# 22  1956972116     neutral
# 23  1956972270       worry
# 24  1956972359     sadness
# 25  1956972444       worry
# 26  1956972557     sadness
# 27  1956972884       worry
# 28  1956973598     sadness
# 29  1956973690       worry
#
# ...
